# %%
using Pkg
Pkg.add("Javis")
# Out:
#     Updating registry at `~/.julia/registries/General`
#    Resolving package versions...
#    Installed iso_codes_jll ───────────── v4.3.0+4
#    Installed Ogg_jll ─────────────────── v1.3.5+1
#    Installed StatsPlots ──────────────── v0.13.0
#    Installed Dbus_jll ────────────────── v1.12.16+3
#    Installed ATK_jll ─────────────────── v2.36.1+0
#    Installed Wayland_protocols_jll ───── v1.23.0+0
#    Installed at_spi2_atk_jll ─────────── v2.34.1+4
#    Installed Quaternions ─────────────── v0.4.2
#    Installed XLSX ────────────────────── v0.6.2
#    Installed Xorg_libXdamage_jll ─────── v1.1.5+4
#    Installed FilePathsBase ───────────── v0.7.0
#    Installed PlotThemes ──────────────── v0.4.0
#    Installed Distributions ───────────── v0.21.12
#    Installed CatIndices ──────────────── v0.2.2
#    Installed FFTViews ────────────────── v0.3.2
#    Installed Xorg_libXcomposite_jll ──── v0.4.5+4
#    Installed Hungarian ───────────────── v0.6.0
# ...

# %%
using Javis
# Out:
# ┌ Info: Precompiling Javis [78b212ba-a7f9-42d4-b726-60726080707e]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 549154189286137 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 549154189286137 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 549154189286137 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 549154189286137 is missing from the cache.
# ...
